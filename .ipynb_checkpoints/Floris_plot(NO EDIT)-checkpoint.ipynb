# %%
import pickle
from Experiment1 import DataTest, DataRun

import pandas as pd

import matplotlib.pyplot as plt


data = pickle.load(open('output\\RUN_DATA_most_random.p', 'rb'))

# %%
lines = []
for d in data:
    names = ['angle', 'moment']
    line = [d.angle, d.moment]
    pre_line = d.properties
    for key, i in pre_line.items():
        if type(i) == list or type(i) == tuple:
            for j in i:
                names.append(key)
                line.append(j)
        else:
            names.append(key)
            line.append(i)
    lines.append(line)


df = pd.DataFrame(lines)
df.columns = names

# %%
df
# Out:
#          angle  moment    max_dist   min_dist    av_dist     av_path  \
# 0   -62.500000    0.80   81.746894  31.043693  22.396589  104.641818
# 1  -215.600000    0.50   86.040087  30.646379  20.247986   72.077326
# 2  -161.960784    0.35  159.327518  30.718092  21.480535  145.024826
# 3  -100.000000    0.90   71.302313  31.383118  18.958805   75.888121
# 4  -213.414634    0.55   52.400494  32.021851  19.765470   97.699565
# 5   -96.153846    0.80   92.156790  30.560279  20.178990  103.799437
# 6  -196.743787    0.25   82.136502  31.304021  20.328644  101.707745
# 7          NaN    1.00   93.463153  32.071213  22.238452   72.921690
# 8  -126.666667    0.75   70.838503  30.688096  20.114728   95.147264
# 9          NaN    1.00   64.742364  31.057192  19.666265   86.217188
# 10   11.538462    0.90   72.910314  30.928568  19.674004  111.432201
# 11 -200.000000    0.85   55.280527  30.951059  19.205428   88.347212
# 12 -169.354839    0.70   75.704981  30.871923  19.794668   70.140297
# 13 -200.863931    0.30  231.044855  31.264761  24.387079  115.145264
# 14 -131.250000    0.70  154.241829  31.870401  25.140766  106.922176
# 15 -172.199170    0.55  160.464242  31.174934  23.223930  106.580497
# 16 -215.730337    0.45  112.050948  31.390101  22.137030   93.280565
# 17 -183.035714    0.55   91.413163  31.191089  22.495226  102.127383
# 18 -210.373444    0.40  117.894692  31.014471  21.607891   89.718178
# 19 -198.936170    0.50  113.354797  32.093938  23.390573  127.283128
# 20 -221.052632    0.45   95.493776  31.168385  23.737670  114.542094
# 21 -163.636364    0.60   75.268222  31.078651  21.084194   99.621094
# 22 -153.658537    0.70  176.981502  31.676203  22.995689   84.294592
# 23 -203.100775    0.45   67.903857  30.865980  20.611655   85.005159
# 24 -226.923077    0.45   71.257802  31.142883  20.254782   87.903905
# 25 -199.077491    0.40   92.760697  30.579897  21.541057   70.667258
# 26 -197.468354    0.65   71.269122  30.833062  20.044826   84.417337
# 27 -214.019851    0.30   68.645648  30.691142  19.721612  100.674491
# 28 -209.482759    0.60   59.626625  31.535204  19.080290  109.090299
#
#       diameter  tot_degree  tot_degree_type  tot_degree_type  ...  \
# 0   229.104106        34.0                5               16  ...
# 1   106.203452        32.0               17                4  ...
# 2   227.712661        33.0                8                7  ...
# 3   107.965150        30.0                8               10  ...
# 4   229.676563        29.0               20               13  ...
# 5   158.988347        28.0                5               18  ...
# 6   204.805858        34.0               20               14  ...
# 7   112.245585        29.0                5               10  ...
# 8   200.180638        39.0               24               19  ...
# 9   108.316751        34.0                2                9  ...
# 10  170.334531        32.0                4               11  ...
# 11  155.308194        33.0               10               12  ...
# 12  140.816488        27.0               17               17  ...
# 13  215.431645        33.0               26               10  ...
# 14  189.775206        30.0               10               17  ...
# 15  189.668746        31.0               15               16  ...
# 16  149.475251        31.0               15               16  ...
# 17  181.363323        32.0               12                9  ...
# 18  163.519870        37.0               25                9  ...
# 19  256.268386        37.0               24               12  ...
# 20  255.022137        29.0               18               18  ...
# 21  206.813803        32.0               11               26  ...
# 22  157.379912        35.0               13               17  ...
# 23  177.174600        31.0               23               14  ...
# 24  155.929734        28.0               16               11  ...
# 25  116.480736        28.0               14                6  ...
# 26  202.506960        33.0               18               17  ...
# 27  175.595161        31.0               27                7  ...
# 28  232.926902        35.0               17               15  ...
#
#     av_degree_type  av_degree_type  clus_coef_type  clus_coef_type  \
# 0         3.200000        2.230769        0.000000        0.053333
# 1         4.000000        2.083333        0.214762        0.266667
# 2         2.333333        2.307692        0.733333        0.888889
# 3         3.333333        2.000000        0.366667        0.133333
# 4         2.600000        1.800000        0.528571        0.259048
# 5         3.000000        2.444444        0.000000        0.222222
# 6         3.500000        3.400000        0.377778        0.336905
# 7         3.333333        2.000000        0.500000        0.222222
# 8         3.166667        2.200000        0.295238        0.161111
# 9         3.000000        2.285714        0.000000        1.000000
# 10        2.200000        2.700000        1.000000        1.266667
# 11        2.400000        2.545455        0.466667        0.040000
# 12        3.400000        3.000000        0.360000        0.333333
# 13        2.500000        2.000000        0.443333        0.583333
# 14        2.833333        2.571429        0.377778        0.255556
# 15        3.200000        3.000000        0.088889        0.106667
# 16        3.200000        2.444444        0.407143        0.240000
# 17        3.000000        2.000000        0.050000        0.222222
# 18        2.250000        2.857143        0.263690        0.000000
# 19        2.400000        2.400000        0.079167        0.019048
# 20        2.571429        2.166667        0.100000        0.280952
# 21        2.888889        2.444444        0.044444        0.025926
# 22        3.400000        2.600000        0.333333        0.406667
# 23        3.500000        3.500000        0.196667        0.375000
# 24        2.200000        2.375000        0.193333        0.166667
# 25        3.000000        2.181818        0.191667        0.166667
# 26        3.400000        2.222222        0.072222        0.000000
# 27        1.750000        3.800000        0.069697        0.325000
# 28        3.000000        2.090909        0.333333        0.386667
#
#     clus_coef_type  clus_coef_tot  resillience  n_camps  n_nodes  n_links
# 0         0.223626       0.158690         7.73        2       20       34
# 1         0.350000       0.307804         7.23        5       18       32
# 2         0.341758       0.489975         7.67        3       19       33
# 3         0.285714       0.269312         5.30        2       18       30
# 4         0.333333       0.391877         4.40        7       17       29
# 5         0.140741       0.152941         3.48        2       17       28
# 6         0.593333       0.428571         9.51        9       18       34
# 7         0.507143       0.453274         1.00        1       16       29
# 8         0.383333       0.298551         4.57        7       23       39
# 9         0.398639       0.476720         9.44        1       18       34
# 10        0.479719       0.772383         5.15        2       17       32
# 11        0.350000       0.286842         6.65        3       19       33
# 12        0.316667       0.338095         8.02        5       14       27
# 13        0.050000       0.387037         6.29       10       18       33
# 14        0.142857       0.229167         3.10        3       16       30
# 15        0.041667       0.073684         6.97        6       19       31
# 16        0.388889       0.351587         3.99        4       18       31
# 17        0.281685       0.226429         6.60        4       20       32
# 18        0.348980       0.239599         9.08        8       19       37
# 19        0.103333       0.076605         1.00        8       23       37
# 20        0.166667       0.183333         5.05        7       20       29
# 21        0.170370       0.090476         5.54        3       21       32
# 22        0.330000       0.351852         2.07        3       18       35
# 23        0.395833       0.280556         7.54       10       18       31
# 24        0.233333       0.203704         5.18        5       18       28
# 25        0.172727       0.176471         2.61        4       17       28
# 26        0.144444       0.086667         6.95        6       20       33
# 27        0.066667       0.120000         6.17       11       20       31
# 28        0.078788       0.223188         4.80        7       23       35
#
# [29 rows x 22 columns]

# %%
# # [ i for n, i in enumerate(names) if n in [6,8,13]]
# names

# %%
corr_matrix = df.corr()
corr_matrix.iloc[0,1] = -1
corr_matrix.iloc[1,0] = -1
import seaborn as sn
fig = plt.figure(figsize=(16,3))
sn.heatmap(corr_matrix.iloc[:2,:], annot=True)
plt.show()

# %%
fig.savefig('smallcorr2.png')
# corr_matrix.values

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

import pickle
from Experiment1 import DataTest, DataRun
import pandas as pd


data = pickle.load(open('output\\RUN_DATA_100_more_random.p', 'rb'))



lines = []
for d in data:
    names = ['angle', 'moment', 'links', 'n_camp', 'nodes']
    line = [d.angle, d.moment, d.links, d.n_camp, d.nodes]
    pre_line = d.properties
    for key, i in pre_line.items():
        if type(i) == list or type(i) == tuple:
            for j in i:
                names.append(key)
                line.append(j)
        else:
            names.append(key)
            line.append(i)
    lines.append(line)


df = pd.DataFrame(lines)
df.columns = names

fig1 = plt.figure()

corr_matrix = df.corr()
import seaborn as sn
fig = plt.figure(figsize=(16,16))
sn.heatmap(corr_matrix, annot=True)



fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for xs, ys, zs in zip(df['moment'], df['tot_degree_type'].iloc[:,0], df['av_degree_type'].iloc[:,0]):
    ax.scatter(float(xs), float(ys), float(zs))

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
X = df.iloc[:,5:].values
y = [ int(i) if i == i else 0 for i in df['angle'].values * 20 ]

t = 50
train_x = X[:-t]
test_x = X[-t:]

train_y = y[:-t]
test_y = y[-t:]

from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
result = DT.fit(train_x, train_y)


y_pred = result.predict(test_x)

e = 0
for i,j in zip(y_pred, test_y):
    e += abs(i * 0.05 - j * 0.05)
    print(i * 0.05, j * 0.05)

print(e/len(y_pred))
# Out:
# -187.55 -96.80000000000001
# -182.60000000000002 -180.0
# -226.45000000000002 -199.95000000000002
# -139.1 -194.45000000000002
# -164.60000000000002 -299.95
# -211.85000000000002 -192.85000000000002
# -188.05 -101.30000000000001
# -264.7 -209.95000000000002
# -188.05 -47.2
# -175.0 -140.0
# -45.150000000000006 -172.70000000000002
# -140.15 -125.35000000000001
# -150.0 -156.20000000000002
# -81.80000000000001 -191.70000000000002
# -150.0 -183.15
# -150.0 -218.10000000000002
# -139.1 -166.95000000000002
# -149.95000000000002 -197.15
# -42.5 -181.05
# -140.15 -94.2
# -98.9 -199.95000000000002
# -124.95 -44.550000000000004
# -211.85000000000002 -112.45
# -194.10000000000002 -186.9
# -182.60000000000002 -198.8
# -195.70000000000002 -59.95
# -201.85000000000002 -224.0
# -175.0 -188.5
# -209.3 -213.15
# -210.0 -174.95000000000002
# -107.60000000000001 -87.75
# -201.85000000000002 -48.35
# -69.25 -113.45
# -90.05000000000001 -188.15
# -195.70000000000002 -70.5
# -164.60000000000002 -189.25
# -195.70000000000002 0.0
# -174.95000000000002 -99.95
# -174.95000000000002 -88.2
# -215.95000000000002 -170.0
# -177.20000000000002 -237.8
# -188.05 -221.05
# -80.15 -66.75
# -182.60000000000002 -200.0
# -226.45000000000002 -88.2
# -194.10000000000002 -213.25
# -69.25 -147.8
# -188.05 -148.45000000000002
# -264.7 -224.75
# -114.25 -206.5
# 63.63499999999999

# %%
plt.subplot(211)
plt.hist(y_pred)
plt.xticks([])
plt.subplot(212)
plt.hist(test_y)
# Out:
# (array([10.,  4.,  5.,  7.,  8.,  9.,  4.,  2.,  0.,  1.]),
#  array([ 8. ,  9.2, 10.4, 11.6, 12.8, 14. , 15.2, 16.4, 17.6, 18.8, 20. ]),
#  <a list of 10 Patch objects>)

# %%
estimator = DT
X_test = test_x
n_nodes = estimator.tree_.node_count
children_left = estimator.tree_.children_left
children_right = estimator.tree_.children_right
feature = estimator.tree_.feature
threshold = estimator.tree_.threshold

# %%
children_left
# Out:
# array([ 1,  2,  3, -1,  5, -1, -1,  8,  9, 10, 11, 12, -1, -1, 15, 16, 17,
#        18, 19, -1, 21, -1, -1, 24, 25, 26, 27, -1, 29, -1, -1, -1, -1, 34,
#        -1, -1, 37, -1, -1, 40, 41, 42, -1, -1, 45, 46, 47, -1, -1, -1, -1,
#        -1, 53, 54, -1, -1, -1, 58, 59, -1, 61, -1, 63, -1, -1, 66, 67, 68,
#        -1, 70, -1, 72, -1, -1, -1, 76, 77, -1, -1, -1, 81, 82, -1, -1, 85,
#        -1, -1, -1, 89, -1, -1], dtype=int64)

# %%
children_right
# Out:
# array([88,  7,  4, -1,  6, -1, -1, 87, 80, 57, 14, 13, -1, -1, 52, 39, 36,
#        23, 20, -1, 22, -1, -1, 33, 32, 31, 28, -1, 30, -1, -1, -1, -1, 35,
#        -1, -1, 38, -1, -1, 51, 44, 43, -1, -1, 50, 49, 48, -1, -1, -1, -1,
#        -1, 56, 55, -1, -1, -1, 65, 60, -1, 62, -1, 64, -1, -1, 75, 74, 69,
#        -1, 71, -1, 73, -1, -1, -1, 79, 78, -1, -1, -1, 84, 83, -1, -1, 86,
#        -1, -1, -1, 90, -1, -1], dtype=int64)

# %%
feature
# Out:
# array([ 1,  3,  4, -2,  7, -2, -2,  3,  8, 10, 16,  3, -2, -2, 12, 13, 11,
#        14, 16, -2, 10, -2, -2,  3,  8,  7,  9, -2,  0, -2, -2, -2, -2,  9,
#        -2, -2,  1, -2, -2,  4, 15, 13, -2, -2,  1,  7,  5, -2, -2, -2, -2,
#        -2,  0,  7, -2, -2, -2,  5,  1, -2,  3, -2, 11, -2, -2,  3,  0, 11,
#        -2,  7, -2,  0, -2, -2, -2,  8,  1, -2, -2, -2,  4, 10, -2, -2, 15,
#        -2, -2, -2, 15, -2, -2], dtype=int64)

# %%
# The tree structure can be traversed to compute various properties such
# as the depth of each node and whether or not it is a leaf.
node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
is_leaves = np.zeros(shape=n_nodes, dtype=bool)
stack = [(0, -1)]  # seed is the root node id and its parent depth
while len(stack) > 0:
    node_id, parent_depth = stack.pop()
    node_depth[node_id] = parent_depth + 1

    # If we have a test node
    if (children_left[node_id] != children_right[node_id]):
        stack.append((children_left[node_id], parent_depth + 1))
        stack.append((children_right[node_id], parent_depth + 1))
    else:
        is_leaves[node_id] = True

# print("The binary tree structure has %s nodes and has "
#       "the following tree structure:"
#       % n_nodes)
# for i in range(n_nodes):
#     if is_leaves[i]:
#         print("%snode=%s leaf node." % (node_depth[i] * "\t", i))
#     else:
#         print("%snode=%s test node: go to node %s if X[:, %s] <= %s else to "
#               "node %s."
#               % (node_depth[i] * "\t",
#                  i,
#                  children_left[i],
#                  feature[i],
#                  threshold[i],
#                  children_right[i],
#                  ))
# print()

# First let's retrieve the decision path of each sample. The decision_path
# method allows to retrieve the node indicator functions. A non zero element of
# indicator matrix at the position (i, j) indicates that the sample i goes
# through the node j.

node_indicator = estimator.decision_path(X_test)

# Similarly, we can also have the leaves ids reached by each sample.

leave_id = estimator.apply(X_test)

# Now, it's possible to get the tests that were used to predict a sample or
# a group of samples. First, let's make it for the sample.

sample_id = 0
node_index = node_indicator.indices[node_indicator.indptr[sample_id]:
                                    node_indicator.indptr[sample_id + 1]]

print('Rules used to predict sample %s: ' % sample_id)
for node_id in node_index:
    if leave_id[sample_id] == node_id:
        continue

    if (X_test[sample_id, feature[node_id]] <= threshold[node_id]):
        threshold_sign = "<="
    else:
        threshold_sign = ">"

    print("decision id node %s : (X_test[%s, %s] (= %s) %s %s)"
          % (node_id,
             sample_id,
             feature[node_id],
             X_test[sample_id, feature[node_id]],
             threshold_sign,
             threshold[node_id]))

# For a group of samples, we have the following common node.
sample_ids = [0, 1]
common_nodes = (node_indicator.toarray()[sample_ids].sum(axis=0) ==
                len(sample_ids))

common_node_id = np.arange(n_nodes)[common_nodes]

print("\nThe following samples %s share the node %s in the tree"
      % (sample_ids, common_node_id))
print("It is %s %% of all nodes." % (100 * len(common_node_id) / n_nodes,))
# Out:
# The binary tree structure has 91 nodes and has the following tree structure:
# node=0 test node: go to node 1 if X[:, 1] <= 31.753518104553223 else to node 88.
# 	node=1 test node: go to node 2 if X[:, 3] <= 101.22312927246094 else to node 7.
# 		node=2 test node: go to node 3 if X[:, 4] <= 148.35488891601562 else to node 4.
# 			node=3 leaf node.
# 			node=4 test node: go to node 5 if X[:, 7] <= 12.5 else to node 6.
# 				node=5 leaf node.
# 				node=6 leaf node.
# 		node=7 test node: go to node 8 if X[:, 3] <= 171.7389144897461 else to node 87.
# 			node=8 test node: go to node 9 if X[:, 8] <= 33.5 else to node 80.
# 				node=9 test node: go to node 10 if X[:, 10] <= 2.549999952316284 else to node 57.
# 					node=10 test node: go to node 11 if X[:, 16] <= 3.309999942779541 else to node 14.
# 						node=11 test node: go to node 12 if X[:, 3] <= 120.05461120605469 else to node 13.
# 							node=12 leaf node.
# 							node=13 leaf node.
# 						node=14 test node: go to node 15 if X[:, 12] <= 0.625 else to node 52.
# 							node=15 test node: go to node 16 if X[:, 13] <= 0.4416666626930237 else to node 39.
# 								node=16 test node: go to node 17 if X[:, 11] <= 2.8090908527374268 else to node 36.
# 									node=17 test node: go to node 18 if X[:, 14] <= 0.153253972530365 else to node 23.
# 										node=18 test node: go to node 19 if X[:, 16] <= 3.6049998998641968 else to node 20.
# 											node=19 leaf node.
# 											node=20 test node: go to node 21 if X[:, 10] <= 2.100000023841858 else to node 22.
# 												node=21 leaf node.
# 												node=22 leaf node.
# 										node=23 test node: go to node 24 if X[:, 3] <= 142.8830337524414 else to node 33.
# 											node=24 test node: go to node 25 if X[:, 8] <= 28.5 else to node 32.
# 												node=25 test node: go to node 26 if X[:, 7] <= 8.5 else to node 31.
# 													node=26 test node: go to node 27 if X[:, 9] <= 1.375 else to node 28.
# 														node=27 leaf node.
# 														node=28 test node: go to node 29 if X[:, 0] <= 101.62477111816406 else to node 30.
# 															node=29 leaf node.
# 															node=30 leaf node.
# 													node=31 leaf node.
# 												node=32 leaf node.
# 											node=33 test node: go to node 34 if X[:, 9] <= 1.625 else to node 35.
# 												node=34 leaf node.
# 												node=35 leaf node.
# 									node=36 test node: go to node 37 if X[:, 1] <= 31.483802795410156 else to node 38.
# 										node=37 leaf node.
# 										node=38 leaf node.
# 								node=39 test node: go to node 40 if X[:, 4] <= 236.03047943115234 else to node 51.
# 									node=40 test node: go to node 41 if X[:, 15] <= 0.348904013633728 else to node 44.
# 										node=41 test node: go to node 42 if X[:, 13] <= 0.5000000149011612 else to node 43.
# 											node=42 leaf node.
# 											node=43 leaf node.
# 										node=44 test node: go to node 45 if X[:, 1] <= 30.847299575805664 else to node 50.
# 											node=45 test node: go to node 46 if X[:, 7] <= 9.5 else to node 49.
# 												node=46 test node: go to node 47 if X[:, 5] <= 33.5 else to node 48.
# 													node=47 leaf node.
# 													node=48 leaf node.
# 												node=49 leaf node.
# 											node=50 leaf node.
# 									node=51 leaf node.
# 							node=52 test node: go to node 53 if X[:, 0] <= 70.81063842773438 else to node 56.
# 								node=53 test node: go to node 54 if X[:, 7] <= 8.5 else to node 55.
# 									node=54 leaf node.
# 									node=55 leaf node.
# 								node=56 leaf node.
# 					node=57 test node: go to node 58 if X[:, 5] <= 31.5 else to node 65.
# 						node=58 test node: go to node 59 if X[:, 1] <= 30.60764217376709 else to node 60.
# 							node=59 leaf node.
# 							node=60 test node: go to node 61 if X[:, 3] <= 121.49574661254883 else to node 62.
# 								node=61 leaf node.
# 								node=62 test node: go to node 63 if X[:, 11] <= 3.1642857789993286 else to node 64.
# 									node=63 leaf node.
# 									node=64 leaf node.
# 						node=65 test node: go to node 66 if X[:, 3] <= 117.42493057250977 else to node 75.
# 							node=66 test node: go to node 67 if X[:, 0] <= 107.60506439208984 else to node 74.
# 								node=67 test node: go to node 68 if X[:, 11] <= 2.833333373069763 else to node 69.
# 									node=68 leaf node.
# 									node=69 test node: go to node 70 if X[:, 7] <= 12.5 else to node 71.
# 										node=70 leaf node.
# 										node=71 test node: go to node 72 if X[:, 0] <= 50.67063903808594 else to node 73.
# 											node=72 leaf node.
# 											node=73 leaf node.
# 								node=74 leaf node.
# 							node=75 test node: go to node 76 if X[:, 8] <= 32.0 else to node 79.
# 								node=76 test node: go to node 77 if X[:, 1] <= 30.274240493774414 else to node 78.
# 									node=77 leaf node.
# 									node=78 leaf node.
# 								node=79 leaf node.
# 				node=80 test node: go to node 81 if X[:, 4] <= 200.56720733642578 else to node 84.
# 					node=81 test node: go to node 82 if X[:, 10] <= 2.549999952316284 else to node 83.
# 						node=82 leaf node.
# 						node=83 leaf node.
# 					node=84 test node: go to node 85 if X[:, 15] <= 0.11496894434094429 else to node 86.
# 						node=85 leaf node.
# 						node=86 leaf node.
# 			node=87 leaf node.
# 	node=88 test node: go to node 89 if X[:, 15] <= 0.4127451032400131 else to node 90.
# 		node=89 leaf node.
# 		node=90 leaf node.
#
# Rules used to predict sample 0:
# decision id node 0 : (X_test[0, 1] (= 30.617428079665526) <= 31.753518104553223)
# decision id node 1 : (X_test[0, 3] (= 128.9385003510793) > 101.22312927246094)
# decision id node 7 : (X_test[0, 3] (= 128.9385003510793) <= 171.7389144897461)
# decision id node 8 : (X_test[0, 8] (= 34.0) > 33.5)
# decision id node 80 : (X_test[0, 4] (= 190.26830203264802) <= 200.56720733642578)
# decision id node 81 : (X_test[0, 10] (= 2.2) <= 2.549999952316284)
#
# The following samples [0, 1] share the node [0 1 7 8] in the tree
# It is 4.395604395604396 % of all nodes.

# %%
importances = DT.feature_importances_
std = np.std([tree.feature_importances_ for tree in DT.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-180-165a920097a8> in <module>
#       1 importances = DT.feature_importances_
# ----> 2 std = np.std([tree.feature_importances_ for tree in DT.estimators_],
#       3              axis=0)
#       4 indices = np.argsort(importances)[::-1]
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'estimators_'

# %%
dir(DT)
l =  list(zip(DT.feature_importances_, names[5:]))
df[list(imp)[-4:]]
# Out:
#        max_dist    diameter   min_dist     av_path
# 0     92.112419  194.648225  30.468931  108.565523
# 1    134.199144  153.789975  30.484923  109.968719
# 2    118.860334  186.810514  31.711920  115.717286
# 3     85.490156  153.507594  30.761407  105.079664
# 4     50.681035  178.931775  31.266189  111.170619
# 5     48.274390  313.637896  31.666314  183.254822
# 6     96.349790  201.347068  31.073801  117.073873
# 7     55.520224  151.895522  31.634794   94.578403
# 8     54.494924  192.768313  30.972129  125.763592
# 9     84.502176  171.982507  30.746353  105.735928
# 10    90.805877  147.840752  30.617670   89.766122
# 11   104.845497  181.095745  30.537083  123.000848
# 12    71.383118  243.536488  31.110864  163.756589
# 13    66.114523  224.210185  30.701964  129.709705
# 14    68.221564  187.496112  30.832906  131.422610
# 15   510.881450  227.921014  30.914420  145.348104
# 16    84.820850  151.912468  31.717681  111.195968
# 17    82.132245  199.013509  31.789356  107.602016
# 18   137.027990  243.169479  31.671570  128.648716
# 19    67.265445  175.280361  31.884415  107.818553
# 20   191.368517  286.254486  30.947889  124.463018
# 21    90.652399  190.887048  31.374890  130.426516
# 22   103.927271  172.036326  30.849009  112.274805
# 23   139.910366  194.735375  31.435033  127.509179
# 24    53.267444  189.779261  30.954999  118.153624
# 25   101.445009  191.447203  30.755119  119.844251
# 26    50.660244  156.246986  30.828300  102.977407
# 27    82.799475  160.676236  30.932681  116.902288
# 28    61.466805  266.376365  31.008876  139.525659
# 29   112.597143  258.107734  30.939171  123.707924
# ..          ...         ...        ...         ...
# 106   82.348676  193.023706  30.422591  111.109033
# 107  201.029321  385.300546  30.744351  183.310337
# 108   61.363185  254.141454  30.854152  144.535518
# 109   95.226583  202.583700  30.937992  136.758351
# 110   78.459886  253.635207  31.433409  127.248819
# 111   85.185777  146.901337  31.009539  104.869384
# 112   98.152467  255.915063  30.949919  151.185056
# 113  203.678500  269.877671  31.285110  123.531924
# 114   87.041910  214.949330  31.006866  122.661619
# 115   81.038194  220.926062  32.318600  127.094106
# 116  105.460672  252.277787  30.747895  161.622428
# 117  123.347410  214.845688  30.596991  135.258870
# 118   99.952538  206.273180  30.995963  137.856785
# 119   60.077188  194.070027  30.633790  107.195954
# 120  308.208112  166.568858  30.974698  126.937221
# 121   81.392547  155.067982  30.595612  101.791699
# 122   90.363410  136.397510  31.299096  114.132407
# 123   95.603983  212.484474  30.517454  114.934239
# 124   75.399933  199.969496  30.432329  112.071724
# 125   65.358924  148.035323  30.645676   97.652077
# 126   63.323579  190.650726  31.263528  125.116272
# 127   66.553600  179.639059  31.665183  123.474327
# 128   62.541235  250.270365  30.972179  158.927391
# 129   95.672997  188.898857  31.379622  124.661850
# 130  104.534616  266.581350  31.131358  126.491949
# 131   78.672436  253.836919  30.657943  124.411464
# 132   67.917374  220.839386  32.260572  146.300883
# 133  126.731958  197.551277  32.108684  139.343866
# 134  112.760929  231.126960  30.673467  131.703476
# 135  123.694389  176.403476  31.040453  107.397418
#
# [136 rows x 4 columns]

# %%
def sorty(x):
    return x[0]

l.sort(key=sorty)

v, imp = zip(*l)
imp
# Out:
# ('tot_degree_type',
#  'clus_coef_type',
#  'clus_coef_tot',
#  'tot_degree_type',
#  'resillience',
#  'max_dist',
#  'clus_coef_type',
#  'min_dist',
#  'av_dist',
#  'av_degree_type',
#  'tot_degree_type',
#  'av_degree_type',
#  'diameter',
#  'av_degree_type',
#  'tot_degree',
#  'av_path',
#  'clus_coef_type')

# %%
for key in d.properties.keys():
    try:
        fig = plt.figure()

        for d in data:
            plt.scatter(d.properties[key], d.moment)

        plt.title('moment')
        plt.xlabel(key)
        plt.ylabel('FRACTION')
        fig.savefig(key+'.png')
        
    except:
        
        for i in range(len(d.properties[key]))
            fig = plt.figure()
            for d in data:
                plt.scatter(d.properties[key][i], d.moment)

            plt.title('moment')
            plt.xlabel(key + ' ' + str(i))
            plt.ylabel('FRACTION')
            fig.savefig(key+ str(i) + '.png')

plt.show()

# %%
key = 'diameter'



plt.figure()

for d in data[:]:
    plt.scatter((d.properties['av_path'] / d.properties[key]) * d.links, d.moment)

plt.title('moment')
plt.xlabel(key)
plt.ylabel('FRACTION')
# Out:
# Text(0, 0.5, 'FRACTION')

# %%
dir(d)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'angle',
#  'data_list',
#  'links',
#  'moment',
#  'n_camp',
#  'nodes',
#  'phase_change',
#  'properties',
#  'slope']

# %%
d
# Out:
# {}

# %%
200 / 20 * 3.6
# Out:
# 36.0

# %%
def func(x, y):
    return x, y

# %%
func(1, 2)
# Out:
# (1, 2)

# %%
list(zip([1,2,3], [1,2,3], [1,2,3]))
# Out:
# [(1, 1, 1), (2, 2, 2), (3, 3, 3)]

# %%
for i in data[0].data_list:
    plt.scatter(i.fraction, i.time)

# %%
for i in data[1].data_list:
    plt.scatter(i.fraction, i.time)

# %%
fig=  plt.figure(figsize=(8,8))
for i in data[2].data_list:
    plt.scatter(i.fraction, i.data_full[-1]/data[2].n_camp)
    
    
plt.ylabel('Fraction camp full at maturity', fontsize=18)
plt.xlabel('Fraction of capacity', fontsize=18)
plt.title('Phase plot', fontsize=20)
fig.savefig('phase2.png')

# %%
for i in data:
#     print('camp', i.n_camp)
    g = i.data_list[-1]
    i.properties['new'] = (g.data_full[-1]/i.n_camp)

# %%
plt.figure()

for d in data[:]:
    plt.scatter(d.properties['av_path'], d.properties['new'])

plt.title('moment')
plt.xlabel(key)
plt.ylabel('FRACTION')
# Out:
# Text(0, 0.5, 'FRACTION')

# %%
plt.figure()

for d in data[:]:
    plt.scatter(d.properties['diameter'], d.properties['new'])

plt.title('moment')
plt.xlabel(key)
plt.ylabel('FRACTION')
# Out:
# Text(0, 0.5, 'FRACTION')
