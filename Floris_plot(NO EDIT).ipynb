# %%
import pickle
from Experiment1 import DataTest, DataRun

import matplotlib.pyplot as plt


data = pickle.load(open('output\\RUN_DATA_100.p', 'rb'))
# Out:
# Text(0, 0.5, 'FRACTION')

# %%
for key in d.properties.keys():
    try:
        plt.figure()

        plt.subplot(121)
        for d in data:
            plt.scatter(d.properties[key], d.angle)

        plt.title('angle')
        plt.xlabel(key)
        plt.ylabel('FRACTION')

        plt.subplot(122)
        for d in data:
            plt.scatter(d.properties[key], d.moment)

        plt.title('moment')
        plt.xlabel(key)
        plt.ylabel('FRACTION')
    except:
        print(key)

plt.show()
# Out:
# tot_degree_type
# av_degree_type
# clus_coef_type
